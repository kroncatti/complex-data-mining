# %%
import pandas
import matplotlib.pyplot as plt
from pandas.plotting import parallel_coordinates
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
data = pandas.read_csv('periodic_table.csv', sep=',', encoding= 'unicode_escape').dropna()
data.head(5)
# Out:
#     Atomic Number    Element Symbol  Atomic Weight  Period  Group  Phase  \
# 2               3    Lithium     Li       6.941000       2      1  solid
# 3               4  Beryllium     Be       9.012182       2      2  solid
# 4               5      Boron      B      10.811000       2     13  solid
# 10             11     Sodium     Na      22.989769       3      1  solid
# 11             12  Magnesium     Mg      24.305000       3      2  solid
#
#    Most Stable Crystal                  Type  Ionic Radius  ...  Density  \
# 2                  bcc          Alkali Metal          0.76  ...    0.534
# 3                  hex  Alkaline Earth Metal          0.35  ...    1.850
# 4                  rho             Metalloid          0.23  ...    2.340
# 10                 bcc          Alkali Metal          1.00  ...    0.971
# 11                 hex  Alkaline Earth Metal          0.72  ...    1.738
#
#     Melting Point (K)  Boiling Point (K)  Isotopes  Discoverer  \
# ...

# %%
subset = ['Type', 'Atomic Weight', 'Density', 'Specific Heat Capacity']
subset_without_string = ['Atomic Weight', 'Density', 'Specific Heat Capacity']

data_adapted = data[subset]
data_adapted[subset_without_string] = scaler.fit_transform(data_adapted[subset_without_string])


parallel_coordinates(data_adapted, 'Type')
plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left")
plt.show()
# Out:
# c:\Users\kaleb\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# c:\Users\kaleb\Anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
subset = ['Type', 'Atomic Weight', 'Boiling Point (K)']
subset_without_string = ['Atomic Weight', 'Boiling Point (K)']

data_adapted = data[subset]
data_adapted[subset_without_string] = scaler.fit_transform(data_adapted[subset_without_string])


parallel_coordinates(data_adapted, 'Type')
plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left")
plt.show()
# Out:
# c:\Users\kaleb\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# c:\Users\kaleb\Anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
